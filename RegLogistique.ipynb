# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql

data = pd.read_csv('regression_logistique.csv', skiprows=0)
data.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
engine = create_engine('mysql+pymysql://root:Lezoup.012@localhost/log')

data.to_sql(name='csv', con=engine, if_exists='append',index=False, schema='log')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
sns.pairplot(data)

# %%
 sns.lmplot(x ='Age', y ='Purchased', data = data )

# %%
sns.jointplot(x = 'EstimatedSalary', y = 'Age', data = data, color = 'grey')

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fee192405e0>,
# ...
#       dtype=object)

# %%
male = data[data.Gender == 'Male']
female = data[data.Gender =='Female']

Age_M = male.Age
Age_F = female.Age

Salary_M = male.EstimatedSalary
Salary_F = female.EstimatedSalary


plt.scatter(Age_M,Salary_M, c ='red')
plt.scatter(Age_F,Salary_F, c ='blue')

# %%
sns.distplot(Salary_M, color="skyblue", label="Male")
sns.distplot(Salary_F, color="red", label="Female")

# %%
sns.distplot(Age_M, color="skyblue", label="Male")
sns.distplot(Age_F, color="red", label="Female")

# %%
x = data['Age']
y = data['EstimatedSalary']

plt.scatter(x,y)

# %%
from sklearn import linear_model
import numpy as np
from scipy import stats
sns.lmplot(x="Age", y="EstimatedSalary", data=data)

# %%
X = np.array(data['Age'])
y = np.array(data['EstimatedSalary'])
Xx=X.reshape(-1,1)

model = linear_model.LinearRegression()
results = model.fit(Xx, y)

# %%
pd.get_dummies(data=data, columns=['Gender'])

df_getdummy=pd.get_dummies(data=data, columns=['Gender'])
df_getdummy.head() 
#X = df_getdummy.drop('Purchased',axis=1)
#y = df_getdummy['Purchased']
# Out:
#     User ID  Age  EstimatedSalary  Purchased  Gender_Female  Gender_Male
# 0  15624510   19            19000          0              0            1
# 1  15810944   35            20000          0              0            1
# 2  15668575   26            43000          0              1            0
# 3  15603246   27            57000          0              1            0
# 4  15804002   19            76000          0              0            1

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split
